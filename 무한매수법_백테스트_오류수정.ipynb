# %% [markdown]
# <a href="https://colab.research.google.com/github/paulyu8868/Quant_Investment_Server/blob/master/%EB%AC%B4%ED%95%9C%EB%A7%A4%EC%88%98%EB%B2%95_%EB%B0%B1%ED%85%8C%EC%8A%A4%ED%8A%B8_%EC%98%A4%EB%A5%98%EC%88%98%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def round_half_up_to_two(num):
    """
    숫자를 소수점 둘째 자리에서 반올림하는 함수.
    """
    try:
        if isinstance(num, (float, int)):
            num_100 = num * 100  # 소수점 둘째 자리로 변환
            if num_100 - int(num_100) >= 0.5:
                return (int(num_100) + 1) / 100  # 둘째 자리에서 반올림 후 다시 나누기
            else:
                return int(num_100) / 100  # 둘째 자리에서 반올림 후 다시 나누기
        else:
            return num
    except:
        return num

# %%
def get_data(ticker, start, end):
    start_date = start
    end_date = end

    df = yf.download(ticker, start=start_date, end=end_date)
    df = df.drop(columns=['Volume', 'Adj Close'])  # 시가, 고가, 저가, 종가 데이터만 유지
    df.index = df.index.date

    # 각 컬럼에 대해 요소별로 round_half_up_to_two 적용
    df['Open'] = df['Open'].map(round_half_up_to_two)
    df['High'] = df['High'].map(round_half_up_to_two)
    df['Low'] = df['Low'].map(round_half_up_to_two)
    df['Close'] = df['Close'].map(round_half_up_to_two)

    # 등락율 계산
    df['Return'] = df['Close'].pct_change() * 100
    df['Return'] = df['Return'].map(round_half_up_to_two)

    return df

# %%
def buy_shares(funds, price, one_buy_amount, qty, avg_price, holdings):
    qty = one_buy_amount // price # 주문 수량 : 일일 총액의 절반까지 구매 가능, 정수로 주문
    holdings += qty # 보유 주식 수
    funds -= price * qty # 주문 성공한 만큼 자금 차감
    avg_price = ((avg_price * (holdings - qty)) + (price * qty)) / holdings if holdings > 0 else 0
    return funds, avg_price, holdings, qty

# %%
def sell_shares(funds, price, qty_sell, holdings):
    holdings -= qty_sell
    funds += qty_sell * price
    return funds, holdings

# %%
def quarter_sell_strategy(df, df_res, i, funds, price, avg_price, highest_price, one_buy_amount, holdings, quarter_sell, quarter_count):
    df_res.loc[i, '쿼터 손절'] = 'O'
    quarter_count += 1

    if quarter_count % 10 == 1: # 쿼터 매도 회차 중 최초 한번만 one_buy_amount 계산하고, 이후 10회차까지 매도에 실패했다면, one_buy_amount를 다시 계산
        qty_sell = holdings // 4
        df_res.loc[i, 'MOC 매도'] = qty_sell
        funds, holdings = sell_shares(funds, price, qty_sell, holdings) # 25% 분량을 MOC 매도
        one_buy_amount = funds // 10 # 1회 총액 : 기존 수익과 합산하여 10분할

    else:
      ##<------------------------ 매수 전략 ------------------------>##
      # 평단 - 10% 가격에 LOC 매수
      if price < (avg_price * 0.9):
          funds, avg_price, holdings, qty = buy_shares(funds, price, one_buy_amount, holdings, avg_price, holdings)

      ##<------------------------ 매도 전략 ------------------------>##
      # 보유 수량의 75%: 평단 + 10% 가격에 지정가 매도
      if highest_price >= (avg_price * 1.1):
          qty_sell = holdings * 3 // 4
          funds, holdings = sell_shares(funds, price, qty_sell, holdings)
          quarter_sell = False # 매도 체결 시 쿼터 손절 탈출

      # 나머지 25%: 평단 - 10% 가격에 매도
      if price >= (avg_price * 0.9):
          qty_sell = holdings // 4
          funds, holdings = sell_shares(funds, price, qty_sell, holdings)
          df_res.loc[i, '-10% LOC 매도'] = qty_sell
          quarter_sell = False # 매도 체결 시 쿼터 손절 탈출

    return funds, avg_price, holdings, quarter_sell, quarter_count

# %%
# normal_buy_strategy와 normal_sell_strategy 부분에서 'holdings'를 직접 수정하는 대신
# 새로운 값을 반환하도록 수정

def normal_buy_strategy(df, df_res, i, funds, price, avg_price, one_buy_amount, holdings, T, is_first_period):
    star_percent_price = round_half_up_to_two(avg_price * (1 + (10 - T / 2) / 100))
    df_res.loc[i, '쿼터 손절'] = 'X'
    new_holdings = holdings  # 초기값 설정

    if is_first_period:
        funds, avg_price, new_holdings, qty = buy_shares(funds, price, one_buy_amount, 0, avg_price, holdings)
        df_res.loc[i, 'LOC 평단 매수'] = qty
        is_first_period = False

    else:  # 첫 회차가 아닌 모든 경우
        if T < 20:
            if price <= avg_price:
                funds, avg_price, new_holdings, qty = buy_shares(funds, price, one_buy_amount / 2, holdings, avg_price, holdings)
                df_res.loc[i, 'LOC 평단 매수'] = qty

            if price < star_percent_price:
                funds, avg_price, new_holdings, qty = buy_shares(funds, price, one_buy_amount / 2, new_holdings, avg_price, new_holdings)
                df_res.loc[i, 'LOC 큰 매수'] = qty

        elif T >= 20:
            if price < star_percent_price:
                funds, avg_price, new_holdings, qty = buy_shares(funds, price, one_buy_amount, holdings, avg_price, holdings)
                df_res.loc[i, 'LOC 큰 매수'] = qty

    df_res.loc[i, '평균단가'] = round_half_up_to_two(avg_price)

    return funds, avg_price, new_holdings, is_first_period

# %%
def normal_sell_strategy(df, df_res, i, price, avg_price, highest_price, holdings, funds, star_percent_price, is_first_period):
    # 매도 전략 (보유 수량의 75%: 평단 + 10% 가격에 지정가 매도)
    holdings_75  = holdings * 3 // 4
    holdings_25  = holdings // 4
    existing_holdings = holdings # holdings의 변경 여부 판단

    if highest_price >= (avg_price * 1.1): # 지정가 매도이므로, price가 아닌 highest_price와 비교
        if holdings == 1:
           qty_sell = 1 # 보유 주식 수가 1개인 경우 + 10% 가격에 지정가 매도
        else:
           qty_sell = holdings_75
        funds, holdings = sell_shares(funds, price, qty_sell, holdings)
        df_res.loc[i, '10% 지정가 매도'] = qty_sell

    # 매도 전략 (나머지 25%: 별% 가격에 LOC 매도)
    if price >= star_percent_price:
        qty_sell = holdings_25
        funds, holdings = sell_shares(funds, price, qty_sell, holdings)
        df_res.loc[i, 'LOC 별% 매도'] = qty_sell

    if existing_holdings != holdings and holdings == 0: # holidings가 변화했으면서, 보유 수량이 0이 된 경우
      is_first_period = True # 첫회차부터 다시 반복

    return funds, holdings, is_first_period

# %%
# 무한 매수법 시뮬레이션 함수
def infinite_buy_simulation(df, df_res, initial_funds, buy_portion, start_idx, simulation_period):
    funds = initial_funds
    one_buy_amount = initial_funds / buy_portion # 한 회차 매수액
    holdings = 0 # 보유 주식 수
    avg_price = 0 # 평단가
    quarter_sell = False
    quarter_count = 0 # 쿼터 매도 회차
    is_first_period = True # 첫 회차 매수

    # DataFrame 인덱스 초기화
    df_res = df_res.reindex(index=range(start_idx, start_idx + simulation_period + 1))

    for i in range(start_idx, start_idx + simulation_period + 1): # start ~ end까지의 시뮬레이션 진행
        # 데이터 할당 방식 수정
        df_res.at[i, '날짜'] = df.index[i]
        df_res.at[i, '시가'] = float(df['Open'].iloc[i])
        df_res.at[i, '고가'] = float(df['High'].iloc[i])
        df_res.at[i, '종가'] = float(df['Close'].iloc[i])
        df_res.at[i, '등락율'] = f"{round_half_up_to_two(df['Return'].iloc[i])}%"

        price = float(df['Close'].iloc[i])
        highest_price = float(df['High'].iloc[i])
        T = round_half_up_to_two((holdings * avg_price) / one_buy_amount)
        df_res.at[i, '별% 값'] = f"{round_half_up_to_two(10 - T / 2)}%"


        if 39 < T <= 40:
            quarter_sell = True

        if quarter_sell: # 쿼터 손절 모드
            df_res.loc[i, '별% 가격'] = 'Invalid' # 쿼터 매도에서는 별% 가격을 사용하지 않음
            funds, avg_price, holdings, quarter_sell, quarter_count = quarter_sell_strategy(
                df, df_res, i, funds, price, avg_price, highest_price, one_buy_amount, holdings, quarter_sell, quarter_count)
        else:
            # normal_buy_strategy에 의해 늘어난 holdings가 normal_sell_strategy의 holdings에 영향을 미치면 안됨. (LOC 매수이므로)
            funds, avg_price, new_buy_holdings, is_first_period = normal_buy_strategy(df, df_res, i, funds, price, avg_price, one_buy_amount, holdings, T, is_first_period)
            star_percent_price = round_half_up_to_two(avg_price * (1 + (10 - T / 2) / 100))
            df_res.loc[i, '별% 가격'] = star_percent_price
            funds, new_sell_holdings, is_first_period = normal_sell_strategy(df, df_res, i, price, avg_price, highest_price, holdings, funds, star_percent_price, is_first_period)

            # holdings 업데이트
            increment = new_buy_holdings - holdings # 새로 산 주식 수
            decrement = holdings - new_sell_holdings # 판매한 주식 수
            holdings = holdings + increment - decrement

        df_res.loc[i, '보유 주식 수'] = holdings
        df_res.loc[i, '예수금'] = funds
        df_res.loc[i, '총 평가액'] = funds + (price * holdings)
        df_res.loc[i, '수익율(%)'] = "0.0%" if holdings == 0 else f"{round_half_up_to_two((price * holdings - avg_price * holdings) / (avg_price * holdings) * 100)}%"


    final_value = funds + (holdings * df['Close'].iloc[start_idx + simulation_period])

    return round_half_up_to_two((final_value / initial_funds - 1) * 100), df_res, final_value

# %%
from datetime import datetime, timedelta
from IPython.display import display

# 시뮬레이션 시작일과 종료일 설정
start_date = '2020-01-01'
end_date = '2022-01-31'

# 초기 자본금, 분할 횟수 설정
initial_funds = 40000
buy_portion = 40 # 40분할 적용

end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')
next_day = end_date_dt + timedelta(days=1) # 하루 다음 날로 변환
end_day_next = next_day.strftime('%Y-%m-%d') # 다시 문자열로 변환

df = get_data(ticker='TQQQ', start=start_date, end=end_day_next) # end 날짜는 포함되지 않으므로, 종료일의 다음날을 전달
df_res = pd.DataFrame(columns = ['날짜', '시가', '고가', '종가', '등락율', '별% 값', '별% 가격', 'LOC 평단 매수', 'LOC 큰 매수', '10% 지정가 매도', 'LOC 별% 매도', 'MOC 매도', '-10% LOC 매도', '보유 주식 수', '쿼터 손절', '평균단가', '예수금', '총 평가액', '수익율(%)'])

# 1회차 매수액을 $1000로 가정
return_rate, df_res, final_value = infinite_buy_simulation(df, df_res, initial_funds=initial_funds, buy_portion=buy_portion, start_idx=0, simulation_period=len(df)-1)

# 결측 값 대체
df_res.loc[0, '등락율'] = 'Irrelavant' # 첫째날의 등락률을 표기하지 않음.
df_res.loc[0, '별% 가격'] = 'Invalid'
df_res = df_res.fillna(0)

# 결측 값 대체 전에 데이터 타입 확인
numeric_columns = ['LOC 평단 매수', 'LOC 큰 매수', '10% 지정가 매도', 'LOC 별% 매도',
                  'MOC 매도', '-10% LOC 매도', '보유 주식 수']

# 각 컬럼의 데이터를 확인하고 안전하게 변환
for col in numeric_columns:
    # 숫자가 아닌 값을 NaN으로 변환
    df_res[col] = pd.to_numeric(df_res[col], errors='coerce')
    # NaN을 0으로 채우고 정수로 변환
    df_res[col] = df_res[col].fillna(0).astype('Int64')

# 중앙 정렬하여 출력
df_res_style = df_res.style.set_properties(**{'text-align': 'center'})  # 중앙 정렬 설정
display(df_res_style)  # DataFrame 출력

print()
print('<------------------ ' + start_date + " ~ " + end_date + ' 동안의 자산 변동 결과 ------------------>')
print('최초 보유 금액:', end=' ')
print(initial_funds)
print('최종 보유 금액:', end=' ')
print(final_value)
print('원금 변화율:', end=' ')
print(str(return_rate) + '%')
print('<----------------------------------------------------------------------------------->')
# Out:
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-23-dcd4f5dd1a6c>:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   df_res.at[i, '시가'] = float(df['Open'].iloc[i])
# <ipython-input-23-dcd4f5dd1a6c>:18: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   df_res.at[i, '고가'] = float(df['High'].iloc[i])
# <ipython-input-23-dcd4f5dd1a6c>:19: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   df_res.at[i, '종가'] = float(df['Close'].iloc[i])
# <ipython-input-23-dcd4f5dd1a6c>:22: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(df['Close'].iloc[i])
# <ipython-input-23-dcd4f5dd1a6c>:23: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   highest_price = float(df['High'].iloc[i])
# <ipython-input-24-ae5d46ed89aa>:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_res = df_res.fillna(0)
# <style type="text/css">
# #T_a1813_row0_col0, #T_a1813_row0_col1, #T_a1813_row0_col2, #T_a1813_row0_col3, #T_a1813_row0_col4, #T_a1813_row0_col5, #T_a1813_row0_col6, #T_a1813_row0_col7, #T_a1813_row0_col8, #T_a1813_row0_col9, #T_a1813_row0_col10, #T_a1813_row0_col11, #T_a1813_row0_col12, #T_a1813_row0_col13, #T_a1813_row0_col14, #T_a1813_row0_col15, #T_a1813_row0_col16, #T_a1813_row0_col17, #T_a1813_row0_col18, #T_a1813_row1_col0, #T_a1813_row1_col1, #T_a1813_row1_col2, #T_a1813_row1_col3, #T_a1813_row1_col4, #T_a1813_row1_col5, #T_a1813_row1_col6, #T_a1813_row1_col7, #T_a1813_row1_col8, #T_a1813_row1_col9, #T_a1813_row1_col10, #T_a1813_row1_col11, #T_a1813_row1_col12, #T_a1813_row1_col13, #T_a1813_row1_col14, #T_a1813_row1_col15, #T_a1813_row1_col16, #T_a1813_row1_col17, #T_a1813_row1_col18, #T_a1813_row2_col0, #T_a1813_row2_col1, #T_a1813_row2_col2, #T_a1813_row2_col3, #T_a1813_row2_col4, #T_a1813_row2_col5, #T_a1813_row2_col6, #T_a1813_row2_col7, #T_a1813_row2_col8, #T_a1813_row2_col9, #T_a1813_row2_col10, #T_a1813_row2_col11, #T_a1813_row2_col12, #T_a1813_row2_col13, #T_a1813_row2_col14, #T_a1813_row2_col15, #T_a1813_row2_col16, #T_a1813_row2_col17, #T_a1813_row2_col18, #T_a1813_row3_col0, #T_a1813_row3_col1, #T_a1813_row3_col2, #T_a1813_row3_col3, #T_a1813_row3_col4, #T_a1813_row3_col5, #T_a1813_row3_col6, #T_a1813_row3_col7, #T_a1813_row3_col8, #T_a1813_row3_col9, #T_a1813_row3_col10, #T_a1813_row3_col11, #T_a1813_row3_col12, #T_a1813_row3_col13, #T_a1813_row3_col14, #T_a1813_row3_col15, #T_a1813_row3_col16, #T_a1813_row3_col17, #T_a1813_row3_col18, #T_a1813_row4_col0, #T_a1813_row4_col1, #T_a1813_row4_col2, #T_a1813_row4_col3, #T_a1813_row4_col4, #T_a1813_row4_col5, #T_a1813_row4_col6, #T_a1813_row4_col7, #T_a1813_row4_col8, #T_a1813_row4_col9, #T_a1813_row4_col10, #T_a1813_row4_col11, #T_a1813_row4_col12, #T_a1813_row4_col13, #T_a1813_row4_col14, #T_a1813_row4_col15, #T_a1813_row4_col16, #T_a1813_row4_col17, #T_a1813_row4_col18, #T_a1813_row5_col0, #T_a1813_row5_col1, #T_a1813_row5_col2, #T_a1813_row5_col3, #T_a1813_row5_col4, #T_a1813_row5_col5, #T_a1813_row5_col6, #T_a1813_row5_col7, #T_a1813_row5_col8, #T_a1813_row5_col9, #T_a1813_row5_col10, #T_a1813_row5_col11, #T_a1813_row5_col12, #T_a1813_row5_col13, #T_a1813_row5_col14, #T_a1813_row5_col15, #T_a1813_row5_col16, #T_a1813_row5_col17, #T_a1813_row5_col18, #T_a1813_row6_col0, #T_a1813_row6_col1, #T_a1813_row6_col2, #T_a1813_row6_col3, #T_a1813_row6_col4, #T_a1813_row6_col5, #T_a1813_row6_col6, #T_a1813_row6_col7, #T_a1813_row6_col8, #T_a1813_row6_col9, #T_a1813_row6_col10, #T_a1813_row6_col11, #T_a1813_row6_col12, #T_a1813_row6_col13, #T_a1813_row6_col14, #T_a1813_row6_col15, #T_a1813_row6_col16, #T_a1813_row6_col17, #T_a1813_row6_col18, #T_a1813_row7_col0, #T_a1813_row7_col1, #T_a1813_row7_col2, #T_a1813_row7_col3, #T_a1813_row7_col4, #T_a1813_row7_col5, #T_a1813_row7_col6, #T_a1813_row7_col7, #T_a1813_row7_col8, #T_a1813_row7_col9, #T_a1813_row7_col10, #T_a1813_row7_col11, #T_a1813_row7_col12, #T_a1813_row7_col13, #T_a1813_row7_col14, #T_a1813_row7_col15, #T_a1813_row7_col16, #T_a1813_row7_col17, #T_a1813_row7_col18, #T_a1813_row8_col0, #T_a1813_row8_col1, #T_a1813_row8_col2, #T_a1813_row8_col3, #T_a1813_row8_col4, #T_a1813_row8_col5, #T_a1813_row8_col6, #T_a1813_row8_col7, #T_a1813_row8_col8, #T_a1813_row8_col9, #T_a1813_row8_col10, #T_a1813_row8_col11, #T_a1813_row8_col12, #T_a1813_row8_col13, #T_a1813_row8_col14, #T_a1813_row8_col15, #T_a1813_row8_col16, #T_a1813_row8_col17, #T_a1813_row8_col18, #T_a1813_row9_col0, #T_a1813_row9_col1, #T_a1813_row9_col2, #T_a1813_row9_col3, #T_a1813_row9_col4, #T_a1813_row9_col5, #T_a1813_row9_col6, #T_a1813_row9_col7, #T_a1813_row9_col8, #T_a1813_row9_col9, #T_a1813_row9_col10, #T_a1813_row9_col11, #T_a1813_row9_col12, #T_a1813_row9_col13, #T_a1813_row9_col14, #T_a1813_row9_col15, #T_a1813_row9_col16, #T_a1813_row9_col17, #T_a1813_row9_col18, #T_a1813_row10_col0, #T_a1813_row10_col1, #T_a1813_row10_col2, #T_a1813_row10_col3, #T_a1813_row10_col4, #T_a1 ...
# <------------------ 2020-01-01 ~ 2022-01-31 동안의 자산 변동 결과 ------------------>
# 최초 보유 금액: 40000
# 최종 보유 금액: Ticker
# TQQQ    60252.47
# Name: 2022-01-31, dtype: float64
# 원금 변화율: Ticker
# TQQQ    50.631175
# Name: 2022-01-31, dtype: float64%
# <----------------------------------------------------------------------------------->
